# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/mlLab/winequality-red.csv'

df = pd.read_csv(path, sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(df.info())
print(df['quality'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
X = df.drop('quality', axis=1)
y = df['quality']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    stratify=y)

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(7, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
y = y - y.min()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    stratify=y)

# %%
history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=50,
                    batch_size=16,
                    verbose=1)
# Out:
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4136 - loss: 1.6147 - val_accuracy: 0.5352 - val_loss: 1.2703
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5971 - loss: 1.1189 - val_accuracy: 0.5781 - val_loss: 1.1727
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6200 - loss: 0.9621 - val_accuracy: 0.5703 - val_loss: 1.1425
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6426 - loss: 0.9306 - val_accuracy: 0.5625 - val_loss: 1.1281
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6267 - loss: 0.9537 - val_accuracy: 0.5820 - val_loss: 1.1186
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6226 - loss: 0.8798 - val_accuracy: 0.5742 - val_loss: 1.1168
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6456 - loss: 0.8672 - val_accuracy: 0.5820 - val_loss: 1.1235
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6663 - loss: 0.8322 - val_accuracy: 0.5977 - val_loss: 1.1186
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6368 - loss: 0.8894 - val_accuracy: 0.5859 - val_loss: 1.1115
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6497 - loss: 0.8212 - val_accuracy: 0.5859 - val_loss: 1.1065
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6293 - loss: 0.8448 - val_accuracy: 0.5742 - val_loss: 1.1105
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6500 - loss: 0.8091 - val_accuracy: 0.5742 - val_loss: 1.1022
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6545 - loss: 0.8387 - val_accuracy: 0.5977 - val_loss: 1.1024
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6691 - loss: 0.7933 - val_accuracy: 0.5703 - val_loss: 1.1041
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6551 - loss: 0.7981 - val_accuracy: 0.5742 - val_loss: 1.1019
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6625 - loss: 0.7692 - val_accuracy: 0.5664 - val_loss: 1.1094
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6542 - loss: 0.7877 - val_accuracy: 0.5820 - val_loss: 1.1003
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6769 - loss: 0.7632 - val_accuracy: 0.5820 - val_loss: 1.1044
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6798 - loss: 0.7696 - val_accuracy: 0.5742 - val_loss: 1.0993
# Epoch 20/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6937 - loss: 0.7427 - val_accuracy: 0.5820 - val_loss: 1.0990
# Epoch 21/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6957 - loss: 0.7114 - val_accuracy: 0.5703 - val_loss: 1.0946
# Epoch 22/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7064 - loss: 0.7434 - val_accuracy: 0.5625 - val_loss: 1.0999
# Epoch 23/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6885 - loss: 0.7295 - val_accuracy: 0.5781 - val_loss: 1.1083
# Epoch 24/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6931 - loss: 0.7053 - val_accuracy: 0.5664 - val_loss: 1.1020
# Epoch 25/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6663 - loss: 0.7892 - val_accuracy: 0.5820 - val_loss: 1.1050
# Epoch 26/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7052 - loss: 0.6932 - val_accuracy: 0.5742 - val_loss: 1.1049
# Epoch 27/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7039 - loss: 0.7132 - val_accuracy: 0.5703 - val_loss: 1.1119
# Epoch 28/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6741 - loss: 0.7593 - val_accuracy: 0.5625 - val_loss: 1.1212
# Epoch 29/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7231 - loss: 0.6971 - val_accuracy: 0.5898 - val_loss: 1.1286
# Epoch 30/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7155 - loss: 0.7012 - val_accuracy: 0.5625 - val_loss: 1.1203
# Epoch 31/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7316 - loss: 0.6461 - val_accuracy: 0.5820 - val_loss: 1.1118
# Epoch 32/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7146 - loss: 0.6715 - val_accuracy: 0.5625 - val_loss: 1.1271
# Epoch 33/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7002 - loss: 0.6937 - val_accuracy: 0.5664 - val_loss: 1.1170
# Epoch 34/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7340 - loss: 0.6599 - val_accuracy: 0.5742 - val_loss: 1.1400
# Epoch 35/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7314 - loss: 0.6589 - val_accuracy: 0.5625 - val_loss: 1.1532
# Epoch 36/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7356 - loss: 0.6405 - val_accuracy: 0.5742 - val_loss: 1.1488
# Epoch 37/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7153 - loss: 0.6378 - val_accuracy: 0.5781 - val_loss: 1.1357
# Epoch 38/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7313 - loss: 0.6307 - val_accuracy: 0.5938 - val_loss: 1.1468
# Epoch 39/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7420 - loss: 0.6102 - val_accuracy: 0.5938 - val_loss: 1.1409
# Epoch 40/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7349 - loss: 0.6085 - val_accuracy: 0.5859 - val_loss: 1.1623
# Epoch 41/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7536 - loss: 0.6120 - val_accuracy: 0.5820 - val_loss: 1.1529
# Epoch 42/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7372 - loss: 0.6219 - val_accuracy: 0.6016 - val_loss: 1.1548
# Epoch 43/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7503 - loss: 0.6022 - val_accuracy: 0.5703 - val_loss: 1.1670
# Epoch 44/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7614 - loss: 0.5924 - val_accuracy: 0.5859 - val_loss: 1.1683
# Epoch 45/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.6092 - val_accuracy: 0.5859 - val_loss: 1.1704
# Epoch 46/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7298 - loss: 0.6025 - val_accuracy: 0.5859 - val_loss: 1.1776
# Epoch 47/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7573 - loss: 0.5839 - val_accuracy: 0.5938 - val_loss: 1.1763
# Epoch 48/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7618 - loss: 0.5682 - val_accuracy: 0.5742 - val_loss: 1.2008
# Epoch 49/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7482 - loss: 0.5837 - val_accuracy: 0.5859 - val_loss: 1.1932
# Epoch 50/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7740 - loss: 0.5651 - val_accuracy: 0.5898 - val_loss: 1.2128

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.2f}')
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5711 - loss: 1.1612
# Test Accuracy: 0.61

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        11
#            2       0.69      0.62      0.65       136
#            3       0.56      0.74      0.64       128
#            4       0.65      0.38      0.48        40
#            5       0.00      0.00      0.00         3
#
#     accuracy                           0.61       320
#    macro avg       0.32      0.29      0.29       320
# weighted avg       0.60      0.61      0.59       320
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
